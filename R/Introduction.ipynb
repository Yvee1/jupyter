# %% [markdown]
# # R Introduction

# %% [markdown]
# Assignments with <-

# %%
a <- 2 + sqrt(5)

# %% [markdown]
# Vectors with the `c` (concatenation) operator

# %%
-c(1, 2, 3, 10)
# Out:
# [1]  -1  -2  -3 -10

# %%
matrix(c(1, 2, 3, 4, 5, 6), 2, 3, byrow=T)
# Out:
#      [,1] [,2] [,3]
# [1,] 1    2    3
# [2,] 4    5    6

# %% [markdown]
# Get working directory

# %%
getwd()
# Out:
# [1] "/media/steven/shared/Documents/Coding/jupyter/R"

# %% [markdown]
# ### Exercise 1

# %%
1 - pchisq(5.2, 3)
# Out:
# [1] 0.1577245

# %% [markdown]
# ### Exercise 2

# %%
qnorm(0.99)
# Out:
# [1] 2.326348

# %% [markdown]
# ### Exercise 3

# %%
rexp(20, 1/3)
# Out:
#  [1]  1.2936633  0.7472256  0.5609845  1.0868527  2.8007971  8.8514954
#  [7]  0.7166118  7.6508766  1.2101686  8.7430488  0.1854439  4.5706615
# [13]  3.3122897  0.5822289  4.5522724  1.2257685  5.4911379 11.0898373
# [19]  0.2799241  8.1943925

# %%
mean(rexp(200000, 1/3))
# Out:
# [1] 2.999533

# %% [markdown]
# ### Exercise 4

# %%
data <- rnorm(40, mean=10, sd=sqrt(2))

# %%
library(MASS)

# %%
truehist(data, nbins=5, col="orange", xlab="5 (actually 6?) bins")
# Out:
# plot without title

# %%
truehist(data, nbins=10, col="orange", xlab="10 bins")
# Out:
# plot without title

# %% [markdown]
# ### Exercise 5
